# %% [markdown]
# # Tennis women data visualization

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# better visuals
sns.set(color_codes=True)  

# You need this for plots to show in notebooks
# %matplotlib inline

# %%
women = pd.read_csv('https://s3-eu-west-1.amazonaws.com/nibble-datasets/tennis/womens_train_file.csv')
women.head(10)
# Out:
#    rally  serve hitpoint      speed  net.clearance  distance.from.sideline  \
# 0      3      2        B  30.940461      -0.183663                1.986714
# 1      3      1        F  29.510526       0.227835                2.871543
# 2      5      1        B  30.851879       0.217549                2.026891
# 3     14      2        B  21.386176       4.543886                0.295634
# 4      3      1        B  33.227040       0.640659                0.603025
# 5     11      2        F  36.645156      -0.244309                2.050255
# 6      8      1        F  31.212889       0.590292                0.176520
# 7      3      1        B  33.684059       1.469188                0.147063
# 8      5      1        B  33.215713       0.391191                1.509905
# 9      4      1        U  15.415033       1.131936                1.411555
#
#       depth  outside.sideline  outside.baseline  player.distance.travelled  \
# ...

# %%
women.describe()
# Out:
#              rally        serve        speed  net.clearance  \
# count  5000.000000  5000.000000  5000.000000    5000.000000
# mean      5.848200     1.375000    30.513612       0.626692
# std       3.293406     0.484171     6.264105       0.917825
# min       3.000000     1.000000     5.176078      -0.988370
# 25%       3.000000     1.000000    27.677631      -0.020280
# 50%       5.000000     1.000000    32.032607       0.457381
# 75%       7.000000     2.000000    34.731247       0.983293
# max      32.000000     2.000000    45.972288       6.560743
#
#        distance.from.sideline        depth  player.distance.travelled  \
# count             5000.000000  5000.000000                5000.000000
# mean                 1.494478     4.268065                   2.481754
# std                  1.134614     3.050976                   1.585767
# min                  0.000497     0.003135                   0.000000
# 25%                  0.532633     1.588008                   1.316889
# ...

# %%
women['rally'].describe()
# Out:
# count    5000.000000
# mean        5.848200
# std         3.293406
# min         3.000000
# 25%         3.000000
# 50%         5.000000
# 75%         7.000000
# max        32.000000
# Name: rally, dtype: float64

# %% [markdown]
# ## Répartition des points gagnants par type de tir

# %%
sns.countplot(x="hitpoint", data=women);

# %% [markdown]
# ## Répartition des points gagnants par catégorie de tir

# %%
sns.countplot(x="outcome", data=women);

# %% [markdown]
# ## Différence de vitesse entre le dernier et l'avant dernier coup

# %%
speed_boxplot = sns.boxplot(x=women['speed'])

# %%
prev_speed_boxplot = sns.boxplot(x=women['previous.speed'])

# %% [markdown]
# ## Informations tout type de coup confondu

# %% [markdown]
# ### Positionnement du gagnant par rapport au filet & la ligne centrale lors du dernier coup, tout type de coup confondu

# %%
plt.figure(figsize=(16, 14))
sns.scatterplot(x="player.impact.depth", y="player.impact.distance.from.center", hue="outcome", data=women);

# %% [markdown]
# ## Informations coups gagnants
#
# ### Vitesse du dernier coup gagnant

# %%
winning = women['outcome'] == 'W'
winning_df = women.loc[winning]

plt.figure(figsize=(16, 3))
winning_speed_boxplot = sns.boxplot(x=winning_df['speed'])

# %% [markdown]
# ### Positionnement du gagnant par rapport à la ligne centrale et au filet pour un coup gagnant

# %%
winning_pos_df = pd.DataFrame()
winning_pos_df['player.impact.distance.from.center'] =  winning_df['player.impact.distance.from.center']
winning_pos_df['player.impact.depth'] = winning_df['player.impact.depth']

plt.figure(figsize=(16, 14))
sns.scatterplot(x="player.impact.depth", y="player.impact.distance.from.center", data=winning_pos_df);

# %% [markdown]
# ### Positionnement du gagnant par rapport à la ligne centrale et au filet en fonction du nombre de coups échangés pour un coup gagnant

# %%
winning_pos_df['rally'] = winning_df['rally']

plt.figure(figsize=(16, 14))
sns.scatterplot(x="player.impact.depth", y="player.impact.distance.from.center", hue='rally', data=winning_pos_df);

# %% [markdown]
# ### Positionnement de l'adversaire à la réception de la balle par rapport à la ligne centrale et au filet pour un coup gagnant

# %%
losing_df = pd.DataFrame()
losing_df['opponent.distance.from.center'] =  winning_df['opponent.distance.from.center']
losing_df['opponent.depth'] = winning_df['opponent.depth']

plt.figure(figsize=(16, 14))
sns.scatterplot(x="opponent.depth", y="opponent.distance.from.center", data=losing_df);

# %% [markdown]
# ### Positionnement de l'adversaire à la réception de la balle par rapport à la ligne centrale et au filet pour un coup gagnant selon le nombre d'échanges

# %%
losing_df['rally'] = winning_df['rally']

plt.figure(figsize=(16, 14))
sns.scatterplot(x="opponent.depth", y="opponent.distance.from.center",hue="rally", data=losing_df);

# %%
df_2 = pd.DataFrame()
df_2['hitpoint'] =  winning_df['hitpoint']
df_2['outcomte'] = winning_df['outcome']
df_2.describe()
# Out:
#        hitpoint outcomte
# count      1668     1668
# unique        4        1
# top           F        W
# freq       1041     1668
